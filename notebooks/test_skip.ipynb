# %%
from pathlib import Path
from omegaconf import OmegaConf
from hydra.utils import instantiate
from dacboenv.policy.sb3_model import ModelPolicy


config_fn = "/scratch/hpc-prf-intexml/cbenjamins/repos/dacboenv/dacboenv/configs/policy/optimized/PPO-RNN-norm/dacbo_Cepisode_length_scaled_plus_logregret_AWEI-skip_Ssawei_Repisode_finished_scaled-DefaultAction_Iackley2d_3seeds/seed1.yaml"

# %% [markdown]
# ```bash
# python -m carps.run hydra.searchpath=[pkg://dacboenv/configs,pkg://adaptaf/configs,pkg://optbench/configs] \
#     +eval=base baserundir=runstest seed=1 \
#     +task/OptBench=Ackley_2 \
#     +policy/optimized/PPO-RNN-norm/dacbo_Cepisode_length_scaled_plus_logregret_AWEI-skip_Ssawei_Repisode_finished_scaled-DefaultAction_Iackley2d_3seeds=seed1
# ```
