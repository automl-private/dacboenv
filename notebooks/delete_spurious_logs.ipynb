# %%
import shutil
from pathlib import Path
from tqdm import tqdm

rundir = "../runsicml"
rundir = "/scratch/hpc-prf-intexml/cbenjamins/repos/dacboenv/runsicml/PPO-AlphaNet/DACBO/dacbo_Cepisode_length_scaled_plus_logregret_AWEI-cont_Ssawei_Repisode_finished_scaled-SAWEI-P_Ibbob2d_3seeds"
target_folder = "smac3_output"
folders_to_delete = list(Path(rundir).glob(f"**/{target_folder}"))

for folder in tqdm(folders_to_delete, total=len(folders_to_delete)):
    print(folder)
    # break
    # shutil.rmtree(folder)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 41610.16it/s]
# /scratch/hpc-prf-intexml/cbenjamins/repos/dacboenv/runsicml/PPO-AlphaNet/DACBO/dacbo_Cepisode_length_scaled_plus_logregret_AWEI-cont_Ssawei_Repisode_finished_scaled-SAWEI-P_Ibbob2d_3seeds/5/smac3_output
# /scratch/hpc-prf-intexml/cbenjamins/repos/dacboenv/runsicml/PPO-AlphaNet/DACBO/dacbo_Cepisode_length_scaled_plus_logregret_AWEI-cont_Ssawei_Repisode_finished_scaled-SAWEI-P_Ibbob2d_3seeds/3/smac3_output
# /scratch/hpc-prf-intexml/cbenjamins/repos/dacboenv/runsicml/PPO-AlphaNet/DACBO/dacbo_Cepisode_length_scaled_plus_logregret_AWEI-cont_Ssawei_Repisode_finished_scaled-SAWEI-P_Ibbob2d_3seeds/1/smac3_output
# /scratch/hpc-prf-intexml/cbenjamins/repos/dacboenv/runsicml/PPO-AlphaNet/DACBO/dacbo_Cepisode_length_scaled_plus_logregret_AWEI-cont_Ssawei_Repisode_finished_scaled-SAWEI-P_Ibbob2d_3seeds/4/smac3_output
# ...
